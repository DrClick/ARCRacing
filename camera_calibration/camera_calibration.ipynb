# %%
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from scipy.misc import imread, imresize
import glob

# %%
# %matplotlib inline
sns.set_context("poster")

# %% [raw]
# #bash command to take pictures every second
# while sleep 1; do raspistill -o checkerboard$(date +"%Y-%M-%d_%H:%M:%S").jpg -t 1; done

# %%
# termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
path = "camera_calibration"
from os import listdir
from os.path import isfile, join
onlyfiles = sorted([int(f.split(".")[0]) for f in listdir(path) if isfile(join(path, f))])[200:]
images = ["camera_calibration/{}.jpg".format(x) for x in onlyfiles if x % 45 == 0]

# %%
len(images)
# Out:
# 169

# %%
nx = 9 # the number of inside corners in x
ny = 6 # the number of inside corners in y

# %%
img = imread("camera_calibration/{}.jpg".format(onlyfiles[0]))
plt.imshow(img)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((nx*ny,3), np.float32)
objp[:,:2] = np.mgrid[0:nx,0:ny].T.reshape(-1,2)

# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

for i, fname in enumerate(images):
    print('processing', i, fname)
    img = imread(fname)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, corners = cv2.findChessboardCorners(gray, (nx, ny), None)
    img = cv2.drawChessboardCorners(img, (nx, ny), corners, True)

    if ret:
        print('FOUND corners!')
        objpoints.append(objp)
        
        corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
        imgpoints.append(corners2)
# Out:
# processing 0 camera_calibration/225.jpg
# processing 1 camera_calibration/270.jpg
# FOUND corners!
# processing 2 camera_calibration/315.jpg
# FOUND corners!
# processing 3 camera_calibration/360.jpg
# FOUND corners!
# processing 4 camera_calibration/405.jpg
# FOUND corners!
# processing 5 camera_calibration/450.jpg
# FOUND corners!
# processing 6 camera_calibration/495.jpg
# FOUND corners!
# processing 7 camera_calibration/540.jpg
# FOUND corners!
# processing 8 camera_calibration/585.jpg
# FOUND corners!
# processing 9 camera_calibration/630.jpg
# FOUND corners!
# processing 10 camera_calibration/675.jpg
# FOUND corners!
# processing 11 camera_calibration/720.jpg
# FOUND corners!
# processing 12 camera_calibration/765.jpg
# processing 13 camera_calibration/810.jpg
# FOUND corners!
# processing 14 camera_calibration/855.jpg
# processing 15 camera_calibration/900.jpg
# FOUND corners!
# processing 16 camera_calibration/945.jpg
# processing 17 camera_calibration/990.jpg
# FOUND corners!
# processing 18 camera_calibration/1035.jpg
# processing 19 camera_calibration/1080.jpg
# FOUND corners!
# processing 20 camera_calibration/1125.jpg
# FOUND corners!
# processing 21 camera_calibration/1170.jpg
# FOUND corners!
# processing 22 camera_calibration/1215.jpg
# FOUND corners!
# processing 23 camera_calibration/1260.jpg
# FOUND corners!
# processing 24 camera_calibration/1305.jpg
# FOUND corners!
# processing 25 camera_calibration/1350.jpg
# FOUND corners!
# processing 26 camera_calibration/1395.jpg
# FOUND corners!
# processing 27 camera_calibration/1440.jpg
# FOUND corners!
# processing 28 camera_calibration/1485.jpg
# FOUND corners!
# processing 29 camera_calibration/1530.jpg
# FOUND corners!
# processing 30 camera_calibration/1575.jpg
# FOUND corners!
# processing 31 camera_calibration/1620.jpg
# FOUND corners!
# processing 32 camera_calibration/1665.jpg
# FOUND corners!
# processing 33 camera_calibration/1710.jpg
# FOUND corners!
# processing 34 camera_calibration/1755.jpg
# FOUND corners!
# processing 35 camera_calibration/1800.jpg
# FOUND corners!
# processing 36 camera_calibration/1845.jpg
# FOUND corners!
# processing 37 camera_calibration/1890.jpg
# FOUND corners!
# processing 38 camera_calibration/1935.jpg
# FOUND corners!
# processing 39 camera_calibration/1980.jpg
# FOUND corners!
# processing 40 camera_calibration/2025.jpg
# FOUND corners!
# processing 41 camera_calibration/2070.jpg
# FOUND corners!
# processing 42 camera_calibration/2115.jpg
# FOUND corners!
# processing 43 camera_calibration/2160.jpg
# FOUND corners!
# processing 44 camera_calibration/2205.jpg
# FOUND corners!
# processing 45 camera_calibration/2250.jpg
# FOUND corners!
# processing 46 camera_calibration/2295.jpg
# processing 47 camera_calibration/2340.jpg
# processing 48 camera_calibration/2385.jpg
# processing 49 camera_calibration/2430.jpg
# processing 50 camera_calibration/2475.jpg
# FOUND corners!
# processing 51 camera_calibration/2520.jpg
# FOUND corners!
# processing 52 camera_calibration/2565.jpg
# FOUND corners!
# processing 53 camera_calibration/2610.jpg
# FOUND corners!
# processing 54 camera_calibration/2655.jpg
# FOUND corners!
# processing 55 camera_calibration/2700.jpg
# processing 56 camera_calibration/2745.jpg
# FOUND corners!
# processing 57 camera_calibration/2790.jpg
# FOUND corners!
# processing 58 camera_calibration/2835.jpg
# FOUND corners!
# processing 59 camera_calibration/2880.jpg
# FOUND corners!
# processing 60 camera_calibration/2925.jpg
# FOUND corners!
# processing 61 camera_calibration/2970.jpg
# FOUND corners!
# processing 62 camera_calibration/3015.jpg
# FOUND corners!
# processing 63 camera_calibration/3060.jpg
# FOUND corners!
# processing 64 camera_calibration/3105.jpg
# FOUND corners!
# processing 65 camera_calibration/3150.jpg
# FOUND corners!
# processing 66 camera_calibration/3195.jpg
# FOUND corners!
# processing 67 camera_calibration/3240.jpg
# FOUND corners!
# processing 68 camera_calibration/3285.jpg
# FOUND corners!
# processing 69 camera_calibration/3330.jpg
# FOUND corners!
# processing 70 camera_calibration/3375.jpg
# FOUND corners!
# processing 71 camera_calibration/3420.jpg
# FOUND corners!
# processing 72 camera_calibration/3465.jpg
# FOUND corners!
# processing 73 camera_calibration/3510.jpg
# FOUND corners!
# processing 74 camera_calibration/3555.jpg
# FOUND corners!
# processing 75 camera_calibration/3600.jpg
# FOUND corners!
# processing 76 camera_calibration/3645.jpg
# processing 77 camera_calibration/3690.jpg
# processing 78 camera_calibration/3735.jpg
# processing 79 camera_calibration/3780.jpg
# processing 80 camera_calibration/3825.jpg
# processing 81 camera_calibration/3870.jpg
# processing 82 camera_calibration/3915.jpg
# processing 83 camera_calibration/3960.jpg
# processing 84 camera_calibration/4005.jpg
# processing 85 camera_calibration/4050.jpg
# processing 86 camera_calibration/4095.jpg
# FOUND corners!
# processing 87 camera_calibration/4140.jpg
# FOUND corners!
# processing 88 camera_calibration/4185.jpg
# FOUND corners!
# processing 89 camera_calibration/4230.jpg
# FOUND corners!
# processing 90 camera_calibration/4275.jpg
# FOUND corners!
# processing 91 camera_calibration/4320.jpg
# FOUND corners!
# processing 92 camera_calibration/4365.jpg
# FOUND corners!
# processing 93 camera_calibration/4410.jpg
# FOUND corners!
# processing 94 camera_calibration/4455.jpg
# FOUND corners!
# processing 95 camera_calibration/4500.jpg
# FOUND corners!
# processing 96 camera_calibration/4545.jpg
# FOUND corners!
# processing 97 camera_calibration/4590.jpg
# FOUND corners!
# processing 98 camera_calibration/4635.jpg
# FOUND corners!
# processing 99 camera_calibration/4680.jpg
# FOUND corners!
# processing 100 camera_calibration/4725.jpg
# FOUND corners!
# processing 101 camera_calibration/4770.jpg
# FOUND corners!
# processing 102 camera_calibration/4815.jpg
# FOUND corners!
# processing 103 camera_calibration/4860.jpg
# FOUND corners!
# processing 104 camera_calibration/4905.jpg
# processing 105 camera_calibration/4950.jpg
# FOUND corners!
# processing 106 camera_calibration/4995.jpg
# processing 107 camera_calibration/5040.jpg
# FOUND corners!
# processing 108 camera_calibration/5085.jpg
# processing 109 camera_calibration/5130.jpg
# processing 110 camera_calibration/5175.jpg
# processing 111 camera_calibration/5220.jpg
# processing 112 camera_calibration/5265.jpg
# processing 113 camera_calibration/5310.jpg
# processing 114 camera_calibration/5355.jpg
# processing 115 camera_calibration/5400.jpg
# processing 116 camera_calibration/5445.jpg
# processing 117 camera_calibration/5490.jpg
# processing 118 camera_calibration/5535.jpg
# processing 119 camera_calibration/5580.jpg
# processing 120 camera_calibration/5625.jpg
# processing 121 camera_calibration/5670.jpg
# processing 122 camera_calibration/5715.jpg
# processing 123 camera_calibration/5760.jpg
# processing 124 camera_calibration/5805.jpg
# processing 125 camera_calibration/5850.jpg
# processing 126 camera_calibration/5895.jpg
# processing 127 camera_calibration/5940.jpg
# processing 128 camera_calibration/5985.jpg
# processing 129 camera_calibration/6030.jpg
# processing 130 camera_calibration/6075.jpg
# processing 131 camera_calibration/6120.jpg
# processing 132 camera_calibration/6165.jpg
# processing 133 camera_calibration/6210.jpg
# processing 134 camera_calibration/6255.jpg
# processing 135 camera_calibration/6300.jpg
# processing 136 camera_calibration/6345.jpg
# processing 137 camera_calibration/6390.jpg
# processing 138 camera_calibration/6435.jpg
# processing 139 camera_calibration/6480.jpg
# processing 140 camera_calibration/6525.jpg
# processing 141 camera_calibration/6570.jpg
# processing 142 camera_calibration/6615.jpg
# processing 143 camera_calibration/6660.jpg
# processing 144 camera_calibration/6705.jpg
# processing 145 camera_calibration/6750.jpg
# processing 146 camera_calibration/6795.jpg
# processing 147 camera_calibration/6840.jpg
# processing 148 camera_calibration/6885.jpg
# processing 149 camera_calibration/6930.jpg
# processing 150 camera_calibration/6975.jpg
# processing 151 camera_calibration/7020.jpg
# processing 152 camera_calibration/7065.jpg
# processing 153 camera_calibration/7110.jpg
# processing 154 camera_calibration/7155.jpg
# processing 155 camera_calibration/7200.jpg
# FOUND corners!
# processing 156 camera_calibration/7245.jpg
# FOUND corners!
# processing 157 camera_calibration/7290.jpg
# FOUND corners!
# processing 158 camera_calibration/7335.jpg
# FOUND corners!
# processing 159 camera_calibration/7380.jpg
# FOUND corners!
# processing 160 camera_calibration/7425.jpg
# FOUND corners!
# processing 161 camera_calibration/7470.jpg
# FOUND corners!
# processing 162 camera_calibration/7515.jpg
# FOUND corners!
# processing 163 camera_calibration/7560.jpg
# FOUND corners!
# processing 164 camera_calibration/7605.jpg
# FOUND corners!
# processing 165 camera_calibration/7650.jpg
# FOUND corners!
# processing 166 camera_calibration/7695.jpg
# FOUND corners!
# processing 167 camera_calibration/7740.jpg
# FOUND corners!
# processing 168 camera_calibration/7785.jpg
# FOUND corners!

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[0:2],None,None)

# %%
img = imread("{}".format(images[70]))

# %%
h,  w = img.shape[:2]
newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),0,(w,h))

plt.subplot(121)
plt.imshow(img)

plt.subplot(122)
undistort = cv2.undistort(img, mtx, dist, None, mtx)
plt.imshow(undistort)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
calibration_data = {
    "mtx": mtx,
    "camera_mtx": newcameramtx,
    "dist": dist
}

# %%
with open("fisheye_f1p8_camera_calibration.pkl", 'wb') as f:
    pickle.dump(calibration_data, f)

# %%
i=0

# %%
img = imread("{}".format(images[i]))
undistort = cv2.undistort(img, mtx, dist, None, mtx)
plt.imshow(undistort)
i += 1
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
