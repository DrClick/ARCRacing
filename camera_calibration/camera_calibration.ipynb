# %%
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from scipy.misc import imread, imresize
import glob

# %%
# %matplotlib inline
sns.set_context("poster")

# %% [raw]
# #bash command to take pictures every second
# while sleep 1; do raspistill -o checkerboard$(date +"%Y-%M-%d_%H:%M:%S").jpg -t 1; done

# %%
# termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
path = "camera_calibration"
from os import listdir
from os.path import isfile, join
onlyfiles = sorted([int(f.split(".")[0]) for f in listdir(path) if isfile(join(path, f))])[200:]
images = ["camera_calibration/{}.jpg".format(x) for x in onlyfiles if x % 90 == 0]

# %%
len(images)
# Out:
# 84

# %%
nx = 9 # the number of inside corners in x
ny = 6 # the number of inside corners in y

# %%
img.shape
# Out:
# (240, 320, 3)

# %%
img = imread("camera_calibration/{}.jpg".format(onlyfiles[0]))
plt.imshow(img)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((nx*ny,3), np.float32)
objp[:,:2] = np.mgrid[0:nx,0:ny].T.reshape(-1,2)

# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.

for i, fname in enumerate(images):
    print('processing', i, fname)
    img = imread(fname)
    img = imresize(img, (480, 640))
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, corners = cv2.findChessboardCorners(gray, (nx, ny), None)
    img = cv2.drawChessboardCorners(img, (nx, ny), corners, True)

    if ret:
        print('FOUND corners!')
        objpoints.append(objp)
        
        corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
        imgpoints.append(corners2)
# Out:
# processing 0 camera_calibration/270.jpg
# FOUND corners!
# processing 1 camera_calibration/360.jpg
# FOUND corners!
# processing 2 camera_calibration/450.jpg
# FOUND corners!
# processing 3 camera_calibration/540.jpg
# FOUND corners!
# processing 4 camera_calibration/630.jpg
# FOUND corners!
# processing 5 camera_calibration/720.jpg
# FOUND corners!
# processing 6 camera_calibration/810.jpg
# FOUND corners!
# processing 7 camera_calibration/900.jpg
# FOUND corners!
# processing 8 camera_calibration/990.jpg
# FOUND corners!
# processing 9 camera_calibration/1080.jpg
# FOUND corners!
# processing 10 camera_calibration/1170.jpg
# FOUND corners!
# processing 11 camera_calibration/1260.jpg
# FOUND corners!
# processing 12 camera_calibration/1350.jpg
# FOUND corners!
# processing 13 camera_calibration/1440.jpg
# FOUND corners!
# processing 14 camera_calibration/1530.jpg
# FOUND corners!
# processing 15 camera_calibration/1620.jpg
# FOUND corners!
# processing 16 camera_calibration/1710.jpg
# FOUND corners!
# processing 17 camera_calibration/1800.jpg
# FOUND corners!
# processing 18 camera_calibration/1890.jpg
# FOUND corners!
# processing 19 camera_calibration/1980.jpg
# FOUND corners!
# processing 20 camera_calibration/2070.jpg
# FOUND corners!
# processing 21 camera_calibration/2160.jpg
# FOUND corners!
# processing 22 camera_calibration/2250.jpg
# FOUND corners!
# processing 23 camera_calibration/2340.jpg
# FOUND corners!
# processing 24 camera_calibration/2430.jpg
# FOUND corners!
# processing 25 camera_calibration/2520.jpg
# FOUND corners!
# processing 26 camera_calibration/2610.jpg
# FOUND corners!
# processing 27 camera_calibration/2700.jpg
# FOUND corners!
# processing 28 camera_calibration/2790.jpg
# FOUND corners!
# processing 29 camera_calibration/2880.jpg
# FOUND corners!
# processing 30 camera_calibration/2970.jpg
# FOUND corners!
# processing 31 camera_calibration/3060.jpg
# FOUND corners!
# processing 32 camera_calibration/3150.jpg
# FOUND corners!
# processing 33 camera_calibration/3240.jpg
# FOUND corners!
# processing 34 camera_calibration/3330.jpg
# FOUND corners!
# processing 35 camera_calibration/3420.jpg
# FOUND corners!
# processing 36 camera_calibration/3510.jpg
# FOUND corners!
# processing 37 camera_calibration/3600.jpg
# FOUND corners!
# processing 38 camera_calibration/3690.jpg
# processing 39 camera_calibration/3780.jpg
# processing 40 camera_calibration/3870.jpg
# processing 41 camera_calibration/3960.jpg
# processing 42 camera_calibration/4050.jpg
# processing 43 camera_calibration/4140.jpg
# FOUND corners!
# processing 44 camera_calibration/4230.jpg
# FOUND corners!
# processing 45 camera_calibration/4320.jpg
# FOUND corners!
# processing 46 camera_calibration/4410.jpg
# FOUND corners!
# processing 47 camera_calibration/4500.jpg
# FOUND corners!
# processing 48 camera_calibration/4590.jpg
# FOUND corners!
# processing 49 camera_calibration/4680.jpg
# FOUND corners!
# processing 50 camera_calibration/4770.jpg
# FOUND corners!
# processing 51 camera_calibration/4860.jpg
# FOUND corners!
# processing 52 camera_calibration/4950.jpg
# FOUND corners!
# processing 53 camera_calibration/5040.jpg
# FOUND corners!
# processing 54 camera_calibration/5130.jpg
# FOUND corners!
# processing 55 camera_calibration/5220.jpg
# FOUND corners!
# processing 56 camera_calibration/5310.jpg
# FOUND corners!
# processing 57 camera_calibration/5400.jpg
# FOUND corners!
# processing 58 camera_calibration/5490.jpg
# FOUND corners!
# processing 59 camera_calibration/5580.jpg
# FOUND corners!
# processing 60 camera_calibration/5670.jpg
# FOUND corners!
# processing 61 camera_calibration/5760.jpg
# FOUND corners!
# processing 62 camera_calibration/5850.jpg
# FOUND corners!
# processing 63 camera_calibration/5940.jpg
# processing 64 camera_calibration/6030.jpg
# FOUND corners!
# processing 65 camera_calibration/6120.jpg
# FOUND corners!
# processing 66 camera_calibration/6210.jpg
# processing 67 camera_calibration/6300.jpg
# processing 68 camera_calibration/6390.jpg
# FOUND corners!
# processing 69 camera_calibration/6480.jpg
# FOUND corners!
# processing 70 camera_calibration/6570.jpg
# FOUND corners!
# processing 71 camera_calibration/6660.jpg
# FOUND corners!
# processing 72 camera_calibration/6750.jpg
# processing 73 camera_calibration/6840.jpg
# FOUND corners!
# processing 74 camera_calibration/6930.jpg
# FOUND corners!
# processing 75 camera_calibration/7020.jpg
# FOUND corners!
# processing 76 camera_calibration/7110.jpg
# FOUND corners!
# processing 77 camera_calibration/7200.jpg
# FOUND corners!
# processing 78 camera_calibration/7290.jpg
# FOUND corners!
# processing 79 camera_calibration/7380.jpg
# FOUND corners!
# processing 80 camera_calibration/7470.jpg
# FOUND corners!
# processing 81 camera_calibration/7560.jpg
# FOUND corners!
# processing 82 camera_calibration/7650.jpg
# FOUND corners!
# processing 83 camera_calibration/7740.jpg
# FOUND corners!

# %%
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[0:2],None,None)

# %%
h,  w = img.shape[:2]
newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),0,(w,h))

plt.subplot(1,3,1)
plt.imshow(img)

plt.subplot(1,3,2)
undistort = cv2.undistort(img, mtx, dist, None, newcameramtx)
plt.imshow(undistort)

plt.subplot(1,3,3)
undistort = cv2.undistort(img, mtx, dist, None, mtx)
plt.imshow(undistort)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
calibration_data = {
    "mtx": mtx,
    "camera_mtx": newcameramtx,
    "dist": dist
}

# %%
with open("fisheye_f1p8_camera_calibration.pkl", 'wb') as f:
    pickle.dump(calibration_data, f)

# %%
i = 0

# %%
img = imread("{}".format(images[i]))
undistort = cv2.undistort(img, mtx, dist, None, mtx)
plt.imshow(undistort)
i += 1
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
